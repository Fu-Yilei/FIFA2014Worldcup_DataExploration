# %%
from datascience import *

# %%
Players = Table().read_table("players.csv")

# %%
Players.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>1</th> <th>GK</th> <th>Jefferson</th> <th>1983</th> <th>1.1</th> <th>2</th> <th>9</th> <th>Botafogo</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>2   </td> <td>DF  </td> <td>Dani Alves                 </td> <td>1983</td> <td>5   </td> <td>6   </td> <td>75  </td> <td>Barcelona                </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>3   </td> <td>DF  </td> <td>Thiago Silva               </td> <td>1984</td> <td>9   </td> <td>22  </td> <td>46  </td> <td>Paris Saint-Germain      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>4   </td> <td>DF  </td> <td>David Luiz                 </td> <td>1987</td> <td>4   </td> <td>22  </td> <td>36  </td> <td>Chelsea                  </td>
#         </tr>
#     </tbody>
#         <tr>
# ...
